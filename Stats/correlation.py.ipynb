# %%
import numpy as np
np.random.seed(1)
# 1000 random integers between 0 and 50
x=np.random.randint(0,50,1000)
# Positive Correlation with some noise
y=x+np.random.randint(0, 10, 1000)

# %%
# Paerson coefficient corrcoef di Numpy
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.98069325],
#        [0.98069325, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
x = np.random.randint(0, 50, 1000)
y = np.random.randint(0, 50, 1000)

np.corrcoef(x, y)
# Out:
# array([[1.        , 0.07441778],
#        [0.07441778, 1.        ]])

# %%
plt.scatter(x, y)
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({'a': np.random.randint(0, 50, 1000)})
df['b'] = df['a'] + np.random.normal(0, 10, 1000) # positively correlated with 'a'
df['c'] = 100 - df['a'] + np.random.normal(0, 5, 1000) # negatively correlated with 'a'
df['d'] = np.random.randint(0, 50, 1000) # not correlated with 'a'

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.833673 -0.943564  0.013651
# b  0.833673  1.000000 -0.779217 -0.000894
# c -0.943564 -0.779217  1.000000 -0.025406
# d  0.013651 -0.000894 -0.025406  1.000000

# %%
pd.pandas.plotting.scatter_matrix(df, figsize=(6, 6))
plt.show()
